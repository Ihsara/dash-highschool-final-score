# %%
import pandas as pd 
from bs4 import BeautifulSoup as bs 
import urllib 


df = pd.read_csv("nhse-dataset/csv/1.csv")

# %%
df
# Out:
#            SBD  TOÁN   VĂN    LÝ   HÓA  SINH    SỬ   ĐỊA  GDCD  ANH  KHTN  \
# 0      1063438   3.0  3.50  2.75  3.25  2.75  2.50  5.50  5.50  2.6  2.92
# 1      1063463   4.0  3.00  2.75  3.75  4.50  1.50  5.00  5.75  3.0  3.67
# 2      1063464   5.0  3.00  3.75  2.25  3.50  3.50  5.75  5.75  3.0  3.17
# 3      1063470   2.6  4.50  2.00  3.50  3.25  1.75  4.25  6.25  3.0  2.92
# 4      1063477   3.2  5.00  2.00  3.00  3.00  2.50  4.00  7.00  3.4  2.67
# 5      1062974   6.6  6.50   NaN   NaN   NaN  4.25  5.25  7.00  5.0   NaN
# 6      1063007   2.4  2.75   NaN   NaN   NaN  2.25  3.50  4.50  2.8   NaN
# 7      1063017   4.4  6.00   NaN   NaN   NaN  3.25  5.25  7.50  3.2   NaN
# 8      1063020   4.2  3.50   NaN   NaN   NaN  2.50  4.00  4.50  2.2   NaN
# 9      1062989   3.4  6.25   NaN   NaN   NaN  5.50  8.50  7.50  2.8   NaN
# 10     1062995   4.0  3.00   NaN   NaN   NaN  4.00  4.25  6.50  3.2   NaN
# 11     1062999   2.8  2.25   NaN   NaN   NaN  2.75  4.75  4.50  2.4   NaN
# ...

# %%
def get_data(query):
    return bs(urllib.request.urlopen(query), 'html.parser')

# %%
query = "https://docs.google.com/spreadsheets/d/1ZZ_jX6o9wNp_loXfThXtux8kZzEkKmrCR8yJMEgj_Tk/edit#gid=1504472318"

soup = get_data(query)

# %%
# %pprint
# Out:
# Pretty printing has been turned ON

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="de"><head><meta content=" Điểm thi THPT Quốc gia 2018 - Trà Vinh (VietNamNet.vn).xlsx" property="og:title"/><meta content="article" property="og:type"/><meta content="Google Docs" property="og:site_name"/><meta content="https://docs.google.com/spreadsheets/d/1ZZ_jX6o9wNp_loXfThXtux8kZzEkKmrCR8yJMEgj_Tk/edit?usp=embed_facebook" property="og:url"/><meta content="https://lh3.googleusercontent.com/rOxwhj-dFal6-FLASaFzMPPCYPUp5S_2oco25JQ1UwVFZUTIguR-1Ntlt226Y6SIBZli1Q=w1200-h630-p" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="630" property="og:image:height"/><meta content="Trà Vinh
#
#  Toán, Văn, Lý, Hóa, Sinh, Sử, Địa, GDCD, Anh, KHTN, KHXH, Khối A, Khối B, Khối C, Khối D, Khối A1
#  58000318, 2, 6, 4, 5, 3, 75, 4, 75, 8, 3, 6, 5, 5, 13, 10, 7
#  58000321, 5, 2, 5, 75, 5, 75, 3, 3, 75, 4, 8, 4, 17, 13, 95, 11, 95, 15, 75, 15, 75
# ...
